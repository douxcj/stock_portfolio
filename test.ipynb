# %%
import pandas as pd
import re
import json
import requests
from io import StringIO
import yfinance as yf
import numpy as np
import plotly.graph_objs as go

# %%
data = yf.download(tickers='AC.TO', period='1Y', interval='1d')
data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2021-04-12  26.650000  27.350000  26.459999  27.000000  27.000000   3723800
# 2021-04-13  28.400000  28.400000  25.200001  26.879999  26.879999  10261700
# 2021-04-14  27.090000  27.299999  26.160000  26.209999  26.209999   4955000
# 2021-04-15  26.299999  26.420000  25.250000  25.430000  25.430000   5522600
# 2021-04-16  25.360001  25.580000  24.650000  24.860001  24.860001   6008100
# ...               ...        ...        ...        ...        ...       ...
# 2022-04-06  23.100000  23.129999  22.559999  22.969999  22.969999   3327900
# 2022-04-07  22.650000  22.650000  22.100000  22.280001  22.280001   3541900
# 2022-04-08  22.240000  22.440001  21.900000  21.940001  21.940001   2648600
# 2022-04-11  21.620001  22.639999  21.450001  22.260000  22.260000   2335800
# ...

# %%
data = data.reset_index()
data['Date_adj'] = data['Date'].dt.strftime('%Y%m%d')
data[data['Date'] == '20220405']['Close'].tolist()[0]
# Out:
# 175.05999755859375

# %%
live_data = yf.download(tickers='CAE', period ='1d', interval='1m')['Close'].tolist()[-1]
live_data
# Out:
# [*********************100%***********************]  1 of 1 completed
# 25.530000686645508

# %%
live_data = yf.download(tickers='CADUSD=X', period ='3m', interval='1m')['Close'].tolist()[-1]
1/live_data
# Out:
# [*********************100%***********************]  1 of 1 completed
# 1.256100059056981

# %%
#declare figure
fig = go.Figure()

#Candlestick
fig.add_trace(go.Candlestick(x=data.index,
                open=data['Open'],
                high=data['High'],
                low=data['Low'],
                close=data['Close'], name = 'market data'))

# Add titles
fig.update_layout(
    title='Apple live share price evolution',
    yaxis_title='Stock Price (USD per Shares)')

# X-Axes
fig.update_xaxes(
    rangeslider_visible=True,
    rangeselector=dict(
        buttons=list([
            dict(count=15, label="15m", step="minute", stepmode="backward"),
            dict(count=45, label="45m", step="minute", stepmode="backward"),
            dict(count=1, label="HTD", step="hour", stepmode="todate"),
            dict(count=3, label="3h", step="hour", stepmode="backward"),
            dict(step="all")
        ])
    )
)

#Show
fig.show()
